# %% [markdown]
# <a href="https://colab.research.google.com/github/Krahjotdaan/MachineLearning/blob/main/KNN_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('telecom_data.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       MA             121        510                 No             Yes
# 1       MO             147        415                Yes              No
# 2       LA             117        408                 No              No
# 3       WV             141        415                Yes             Yes
# 4       IN              65        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3322    AZ             192        415                 No             Yes
# 3323    WV              68        415                 No              No
# 3324    RI              28        510                 No              No
# 3325    CT             184        510                Yes              No
# 3326    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
X = df.drop(columns=['State', 'International plan', 'Voice mail plan', 'Churn'])
y = df['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
acc = []
for k in range(1, 25):
  knn = KNeighborsClassifier(k)
  acc.append(cross_val_score(knn, X_train, y_train).mean())
acc_n = np.array(acc)
acc_n.max(), acc_n.argmax() + 1
# Out:
# (0.8818512148597518, 11)

# %%
df['International plan'] = df['International plan'].replace('Yes', 1)
df['International plan'] = df['International plan'].replace('No', 0)

df['Voice mail plan'] = df['Voice mail plan'].replace('Yes', 1)
df['Voice mail plan'] = df['Voice mail plan'].replace('No', 0)

# %%
X = df.drop(columns=['State', 'Churn'])
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
knn = KNeighborsClassifier(11)
cross_val_score(knn, X_train, y_train).mean()
# Out:
# 0.8818512148597518

# %%
X.columns
# Out:
# Index(['Account length', 'Area code', 'International plan', 'Voice mail plan',
#        'Number vmail messages', 'Total day minutes', 'Total day calls',
#        'Total day charge', 'Total eve minutes', 'Total eve calls',
#        'Total eve charge', 'Total night minutes', 'Total night calls',
#        'Total night charge', 'Total intl minutes', 'Total intl calls',
#        'Total intl charge', 'Customer service calls'],
#       dtype='object')

# %%
for i in X.columns:
  X = df.drop(columns=['State', 'Churn', i])
  y = df['Churn']
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
  knn = KNeighborsClassifier(11)
  print(i, cross_val_score(knn, X_train, y_train).mean())
# Out:
# Account length 0.8832671440632917
# Area code 0.8800825541761782
# International plan 0.8818512148597518
# Voice mail plan 0.8818512148597518
# Number vmail messages 0.8730097876731605
# Total day minutes 0.8616911097908002
# Total day calls 0.8786710028456174
# Total day charge 0.8814972325588668
# Total eve minutes 0.8776090559429626
# Total eve calls 0.8800838049970293
# Total eve charge 0.8818512148597518
# Total night minutes 0.8797310735169954
# Total night calls 0.8804390381187656
# Total night charge 0.8818512148597518
# Total intl minutes 0.8818512148597518
# Total intl calls 0.8818512148597518
# Total intl charge 0.8818512148597518
# Customer service calls 0.8818512148597518

# %%
knn = KNeighborsClassifier(11, weights='distance')
cross_val_score(knn, X_train, y_train).mean()
# Out:
# 0.883620500953751

# %%
knn = KNeighborsClassifier(11, weights='uniform')
cross_val_score(knn, X_train, y_train).mean()
# Out:
# 0.8818512148597518
