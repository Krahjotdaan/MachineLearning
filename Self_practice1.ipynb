# %% [markdown]
# <a href="https://colab.research.google.com/github/Krahjotdaan/MachineLearning/blob/main/Self_practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('wine.csv')
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 167     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 168     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 169     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 170     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 171     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
X = df.drop(columns=['Wine'])
y = df['Wine']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
acc = []
for k in range(2, 50):
  knn = KNeighborsClassifier(k)
  acc.append(cross_val_score(knn, X_train, y_train).mean())
acc_n = np.array(acc)
acc_n.max(), acc_n.argmax() + 1
# Out:
# (0.7473563218390804, 18)

# %%
plt.plot(np.arange(2, 50), acc_n)
plt.title('Accuracy')
plt.show()

# %%
acc = []
for k in range(2, 50):
  knn=KNeighborsClassifier(k)
  knn.fit(X_train,y_train)
  train_pred = knn.predict(X_train)
  test_pred = knn.predict(X_test)
  acc.append(f1_score(y_train, train_pred, average='macro'))

# %%
plt.plot(np.arange(2, 50), acc_n)
plt.title('f1_score')
plt.show()

# %%
acc = []
for k in range(2, 50):
  knn = KNeighborsClassifier(k)
  acc.append(cross_val_score(knn, X_train, y_train).mean())
acc_n = np.array(acc)
